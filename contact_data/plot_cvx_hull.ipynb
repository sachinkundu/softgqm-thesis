# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import numpy as np
rng = np.random.default_rng()
points = rng.random((30, 2))   # 30 random points in 2-D
hull = ConvexHull(points)

# %%
import matplotlib.pyplot as plt
plt.plot(points[:,0], points[:,1], 'o')
for simplex in hull.simplices:
    plt.plot(points[simplex, 0], points[simplex, 1], 'k-')
plt.savefig("convex2d.png", bbox_inches='tight')
plt.show()

# %%
hull.volume
# Out:
# 0.81037869558385

# %%
points3d = rng.random((5, 3))   # 30 random points in 2-D
hull3d = ConvexHull(points3d)

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(points3d[:, 0], points3d[:, 1], points3d[:, 2])

# %%
from mpl_toolkits.mplot3d import Axes3D


fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")

# Plot defining corner points
ax.plot(points3d.T[0], points3d.T[1], points3d.T[2], "ko")

# 12 = 2 * 6 faces are the simplices (2 simplices per square face)
for s in hull3d.simplices:
    s = np.append(s, s[0])  # Here we cycle back to the first coordinate
    ax.plot(points3d[s, 0], points3d[s, 1], points3d[s, 2], "r-")

# Make axis label
for i in ["x", "y", "z"]:
    eval("ax.set_{:s}label('{:s}')".format(i, i))

plt.savefig("convex3d.png", bbox_inches='tight')

plt.show()
